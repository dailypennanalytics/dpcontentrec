# %%
import asyncio
import aiofiles
import aiohttp
import jwt
import pandas as pd
import time
import requests
import numpy as np
from bs4 import BeautifulSoup
import json

## pk = public_key
## secret = private_key
## jwt.encode({'pk': 'payload'}, 'secret', algorithm='HS256')
encoded_jwt = jwt.encode({'pk': 'pk_KoukiYYjUNBNbkXfOv7Lk7gkfNBo5g'}, 'sk_LYtda2Eini8LCUr7yOGbeG0Pb2Geid', algorithm='HS256')

# %%
jwt = encoded_jwt.decode('utf-8')

# %%
async def extract_article_info(session,results,per_page,page):
    per_page=per_page
    page = page
    endpoint = 'https://dpn.ceo.getsnworks.com/v3/content?dir=desc&grid=false&keywords&order=published_at&page={}&per_page={}&status=published&type=article&workflow'.format(page, per_page)
    headers = {"Authorization": "Bearer " + jwt}
    async with session.get(url=endpoint, headers= headers) as data:
        raw = await data.read()
        response = json.loads(raw)
    results.extend(
            [item for item in response['items']])

# %%
uuid = []
ids = []
titles = []
content = []
slugs = []
published_dates = []
abstract = []
title_url = []

# %%
import sys
#start = time.time()
loop = asyncio.get_event_loop()
pages = range(1,10)
response = []
async with aiohttp.ClientSession() as session:
    await asyncio.gather(
            *(extract_article_info(session,response,100, page) for page in pages)
        )
sys.stdout.flush()
#end = time.time()
#print(end - start)

# %%
for item in response:
    uuid.append(item['uuid'])
    ids.append(item['id'])
    titles.append(item['title'])
    title_url.append(item['published_at'][0:4] + "/" + item['published_at'][5:7] + "/" + item['title_url'])
    slugs.append(item['slug'])
    soup = BeautifulSoup(item['content'])
    for script in soup(['script','style']):
        script.decompose()
    content.append(soup.get_text().replace(u'\xa0',u' ').replace("\n"," "))
    published_dates.append(item['published_at'])
    abstract.append(item['abstract'])

# %%
articles_df = pd.DataFrame(data={'id' : ids,'uuid' : uuid,'title': titles, 'slug': slugs, 'content': content, 
                                 'published_date': published_dates,"title_url":title_url})

# %%
articles_df.sort_values("published_date",ascending = False)
# Out:
#          id                                  uuid  \
# 600  186769  abc8e571-3135-4795-863e-8a0212a429ce
# 601  186782  7f6478d6-1a18-4385-b951-aee9a12694cf
# 602  186764  1b7d1461-b79f-4380-bee7-b2d287de5f19
# 603  186638  af9c7a20-1cf0-4fbf-8042-6d4d0696b458
# 604  186761  ad4f6606-2864-427c-a7ed-7560318788d7
# 605  186727  ef0ac9f1-a465-4fe3-8b85-a4292bc9da7e
# 606  186763  3643380b-1ca1-42d1-ab6f-5d4d1253b5a2
# 607  186628  5401c8a2-7b35-4e98-93af-2fbed7de86ed
# 608  186654  3acd12d0-4ca9-4586-9796-07e17952db9c
# 609  186701  4d70aac8-d511-4737-b63b-f0a586f94cce
# 610  186735  e3232d0d-dae2-47e4-b182-4aee8e6f0bf6
# 611  186704  894d04f8-14da-41e6-8850-ba605b18c97b
# 612  186648  e6987a2f-53ce-4e41-8f1d-885609bd7119
# 613  186643  e566f57e-184b-4aff-93b6-bac0456d7169
# 616            2020/01/iran-soleimani-2020-trump-upenn
# 617  2020/01/penn-wrestling-weekend-army-west-point...
# 618  2020/01/penn-womens-track-field-player-week-ni...
# 619  2020/01/penn-mens-womens-squash-trinity-recap-...
# 620  2020/01/penn-mens-womens-swimming-harvard-reca...
# 621  2020/01/penn-gymnastics-george-washington-reca...
# 622  2020/01/penn-mens-womens-fencing-philly-invita...
# 623  2020/01/womens-march-2020-philadelphia-equalit...
# 624  2020/01/penn-mens-basketball-st-joes-recap-aj-...
# 625  2020/01/penn-mens-basketball-live-blog-st-joes...
# 626  2020/01/penn-medicine-vaccine-mice-trial-measl...
# 627       2020/01/drexel-professor-stole-research-fund
# 628  2020/01/penn-womens-basketball-chances-at-larg...
# 629  2020/01/penn-mens-basketball-preview-st-joes-b...
# ..                                                 ...
# 570    2019/09/penn-museum-perfume-oil-making-workshop
# 571  2019/09/upenn-career-services-peer-advisor-rec...
# 572  2019/09/religions-of-anime-course-religious-st...
# 573  2019/09/penn-athletics-center-for-student-athl...
# 574  2019/09/penn-mens-soccer-joey-bhangdia-midfiel...
# 575  2019/09/2019-penn-football-preview-redirect-up...
# 576  2019/09/penn-athletics-roundtable-which-teams-...
# 577  2019/09/penn-football-supplement-photo-essay-u...
# 578  2019/09/undergraduate-assembly-class-board-ele...
# 579  2019/09/philadelphia-mayor-dinner-jim-kenney-p...
# 580  2019/09/cancel-culture-uchicago-ivy-league-saf...
# 581  2019/09/penn-athletics-players-to-watch-soccer...
# 582  2019/09/philadelphia-fury-suspends-operations-...
# 583   2019/09/penn-award-professor-science-engineering
# 584  2019/09/penn-first-plus-office-first-generatio...
# 585  2019/09/penn-football-delaware-preview-season-...
# 586  2019/09/greek-housing-sorority-fraternity-soph...
# 587  2019/09/1-5-minute-climate-lecture-upenn-colle...
# 588  2019/09/mental-health-anxiety-depression-caps-...
# 589  2019/09/penn-research-science-fruit-fly-geneti...
# 590  2019/09/penn-football-preview-column-prove-me-...
# 591  2019/09/pottruck-basketball-courts-reopen-octo...
# 592  2019/09/penn-football-supplement-ivy-league-ro...
# 593  2019/09/penn-football-supplement-wide-receiver...
# 594  2019/09/penn-football-preview-construction-of-...
# 595  2019/09/penn-football-preview-nick-robinson-na...
# 596  2019/09/penn-football-preview-kevin-morris-off...
# 597  2019/09/penn-football-supplement-mohammed-diak...
# 598  2019/09/penn-medicine-research-technology-bloo...
# 599  2019/09/penn-football-running-backs-legacy-kar...
#
# [900 rows x 7 columns]

# %%
# old = pd.read_csv("content.csv")
# old = old.drop(old.columns[0],axis = 1)
# articles_df = pd.concat([old,articles_df],join="inner")
# articles_df = articles_df.drop_duplicates()
# len(articles_df)
# articles_df = articles_df.loc[~(articles_df.published_date.isna()),].sort_values("published_date",ascending = False)
# articles_df.to_csv("content.csv")
# articles_df = articles_df.reset_index().drop("index",axis=1)
# articles_df

# %%
import sqlalchemy as db
from sqlalchemy.dialects.mysql import VARCHAR, TEXT

# %%
admin = 'mysql://root:Da!lyP3nn12!@34.73.151.28/articlecontent'
engine = db.create_engine(admin)
connection = engine.connect()

# %%
pd.read_sql_query("SELECT COUNT(*) FROM content", connection)
# Out:
#    COUNT(*)
# 0     84731

# %%
max_n = pd.read_sql_query("SELECT MAX(published_date) FROM content", connection).iloc[0,0]

# %%
max_n
# Out:
# '2020-01-20 03:02:11'

# %%
articles_df_n = articles_df[articles_df.published_date > max_n]

# %%
articles_df_n.to_sql("content",connection,if_exists = 'append',index = False)

# %%
pd.read_sql_query("SELECT COUNT(*) FROM content", connection)
# Out:
#    COUNT(*)
# 0     84731

# %%
#full_content = pd.read_sql_query("SELECT * FROM content", connection)

# %%
#full_content[full_content.title_url == "2018/03/jetblue-promotes-penn-alumna-to-vice-president-marketing-ivy-league"]
# Out:
#         id                                  uuid  \
# 1858  6645  2f6af3d9-62f7-4651-aa5a-0b37e5de0b2a
#
#                                                   title  \
# 1858  Penn alumna Elizabeth Windram appointed as top...
#
#                                                    slug  \
# 1858  jetblue-promotes-penn-alumna-to-vice-president...
#
#                                               title_url  \
# 1858  2018/03/jetblue-promotes-penn-alumna-to-vice-p...
#
#                                                 content       published_date
# 1858  A Penn alumna has just been appointed as one o...  2018-03-15 03:08:34

# %%
#full_content.to_csv("content.csv")

# %% [markdown]
# # New Articles

# %%
def fetch_new(slug):
    #Make Request
    endpoint = 'https://dpn.ceo.getsnworks.com/v3/search?type=content&keywords=' + slug
    headers = {"Authorization": "Bearer " + jwt}
    r = requests.get(url = endpoint,headers = headers)
    item = r.json()['items'][0]
    
    #Empty Frame
    uuid = []
    ids = []
    titles = []
    content = []
    slugs = []
    published_dates = []
    abstract = []
    title_url = []
    
    #Append Frame
    uuid.append(item['uuid'])
    ids.append(item['id'])
    titles.append(item['title'])
    title_url.append(item['published_at'][0:4] + "/" + item['published_at'][5:7] + "/" + item['title_url'])
    slugs.append(item['slug'])
    soup = BeautifulSoup(item['content'])
    for script in soup(['script','style']):
        script.decompose()
    content.append(soup.get_text().replace(u'\xa0',u' ').replace("\n"," "))
    published_dates.append(item['published_at'])
    abstract.append(item['abstract'])  
    
    #Assemble Frame
    articles_df = pd.DataFrame(data={'id' : ids,'uuid' : uuid,'title': titles, 'slug': slugs, 'content': content, 
                                 'published_date': published_dates,"title_url":title_url})
    
    return(articles_df)

# %%
#fetch_new('penn-two-rhodes-scholars-nurul-hasbullah-stephen-damianos')
# Out:
#        id                                  uuid  \
# 0  185954  b8ac5412-af54-4f28-8d91-8159774e8aaa
#
#                                                title  \
# 0  Penn senior and 2019 graduate win prestigious ...
#
#                                                 slug  \
# 0  penn-two-rhodes-scholars-nurul-hasbullah-steph...
#
#                                              content       published_date  \
# 0  A Penn student and recent graduate were select...  2019-11-25 02:58:12
#
#                                            title_url
# 0  2019/11/penn-two-rhodes-scholars-nurul-hasbull...
